# %% [markdown]
# ## グラフの描き方の基本（折れ線グラフの描き方）

# %% [markdown]
# ### matplotlib.pyplotのインポート

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### グラフ化するデータを読み込む

# %%
df = pd.read_csv("./sample_data/california_housing_train.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
y = df.median_income # .valuesとすればndarrayが取得できるが、そのままで支障ない
y
# Out:
# 0        1.4936
# 1        1.8200
# 2        1.6509
# 3        3.1917
# 4        1.9250
#           ...
# 16995    2.3571
# 16996    2.5179
# 16997    3.0313
# 16998    1.9797
# 16999    3.0147
# Name: median_income, Length: 17000, dtype: float64

# %% [markdown]
# ### グラフを作成する

# %%
plt.plot(y)

# %% [markdown]
# ### 補足：作成したグラフを表示する

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# ### 横軸のデータも用意する

# %%
x = [7, 8, 11, 14, 17, 21, 22, 26, 29, 30]
y = [19, 36, 43, 54, 55, 64, 88, 90, 92, 97]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 線や点のスタイルを指定する

# %%
plt.plot(x, y, linestyle="--", marker="^", color="r")
plt.show()

# %% [markdown]
# ### グラフの部品を追加する

# %%
x = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
y = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.title("Year - Count")
plt.xlabel("Year")
plt.ylabel("Count")
plt.grid(True)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### グラフを保存する

# %%
x = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
y = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.title("Year - Count")
plt.xlabel("Year")
plt.ylabel("Count")
plt.grid(True)

plt.plot(x, y)

# ここで保存
plt.savefig("figure.png")

plt.show()

# %% [markdown]
# ## さまざまなグラフの描き方

# %% [markdown]
# ### 棒グラフ

# %%
year = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
count = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.bar(year, count)
plt.show()

# %%
year = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
count = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.barh(year, count)
plt.show()

# %% [markdown]
# ### 散布図

# %%
x = df.median_house_value
y = df.median_income

plt.scatter(x, y)
plt.xlabel("Median house value")
plt.ylabel("median income")
plt.show()

# %% [markdown]
# ### 円グラフ

# %%
fruits = np.array(["peach", "orange", "grape", "banana", "apple"])
count = np.array([12, 20, 34, 36, 47])

plt.pie(count, labels = fruits, autopct = "%.1f%%", startangle = 90)
plt.show()

# %% [markdown]
# ## 複数のグラフを一度に表示する方法

# %% [markdown]
# ### 1つのグラフ領域に複数のグラフを描く

# %%
y1 = df.population # 人口
y2 = df.households # 世帯数

plt.plot(y1, color="b", label="population")
plt.plot(y2, color="r", label="households")
plt.legend()
plt.show()

# %%
plt.plot(y1, color="b", label="population")
plt.plot(y2, color="r", label="households")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### 複数のグラフを並べて表示する

# %% [markdown]
# #### 横に並べる

# %% [markdown]
# ##### subplot() を使う

# %%
y1 = df.population # 人口
y2 = df.households # 世帯数

# Figureオブジェクトを生成
fig = plt.figure()

# population用の描画領域を作成してグラフを追加
sp1 = fig.add_subplot(1, 2, 1)
sp1.plot(y1)

# households用の描画領域を作成してグラフを追加
sp2 = fig.add_subplot(1, 2, 2)
sp2.plot(y2)

# グラフを表示
plt.show()

# %% [markdown]
# ##### subplots() を使う

# %%
fig, axes = plt.subplots(1, 2) # (縦方向のsubplot数, 横方向)

axes[0].plot(y1)
axes[1].plot(y2)

plt.show()

# %% [markdown]
# #### 縦に並べる

# %%
fig, axes = plt.subplots(2, 1) # (縦方向のsubplot数, 横方向)

axes[0].plot(y1)
axes[1].plot(y2)

plt.show()

# %% [markdown]
# ## グラフのサイズを変更する方法

# %%
fig = plt.figure(figsize=(10, 4))

sp1 = fig.add_subplot(1, 2, 1)
sp1.plot(y1)

sp2 = fig.add_subplot(1, 2, 2)
sp2.plot(y2)
plt.show()

# %% [markdown]
# `figsize`引数に長さ2の数値タブル（リストでも良い）を渡すことで、`(横幅インチ, 縦幅インチ)`を指定することが出来ます。

# %% [markdown]
# この方法は、最初に扱ったような単一グラフでも使えるので、覚えておきましょう。

# %%
x = [7, 8, 11, 14, 17, 21, 22, 26, 29, 30]
y = [19, 36, 43, 54, 55, 64, 88, 90, 92, 97]

plt.figure(figsize=(10, 4))
plt.plot(x, y, ls="--", marker="D", c="r")
plt.show()

# %% [markdown]
# ## 日本語文字をグラフ中に表示する方法

# %%
# とくに何もしなければ日本語の文字が文字化けする
y1 = df.population # 人口
y2 = df.households # 世帯数

plt.scatter(y1, y2)
plt.xlabel("人口")
plt.ylabel("世帯数")
plt.title("カリフォルニア州での人口と世帯数の比較")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19990 (\N{CJK UNIFIED IDEOGRAPH-4E16}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24111 (\N{CJK UNIFIED IDEOGRAPH-5E2F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12459 (\N{KATAKANA LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12522 (\N{KATAKANA LETTER RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# !pip install japanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 33.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=4711782bf604471e71ac2d4152935e05cf2b10cc6fd48304d0c6a47ed5bf55f3
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize_matplotlib
# ...

# %%
import japanize_matplotlib

# %%
# japanize_matplotlibをimportしてから同じコードを再度実行
y1 = df.population # 人口
y2 = df.households # 世帯数

plt.scatter(y1, y2)
plt.xlabel("人口")
plt.ylabel("世帯数")
plt.title("カリフォルニア州での人口と世帯数の比較")
plt.show()

# %% [markdown]
# ## 応用例：近似直線の描き方

# %%
# サンプルデータ
x = np.array([20, 30, 40, 50, 60, 43, 94, 24, 44])
y = np.array([30, 38, 41, 49, 62, 59, 61, 43, 24])

# 近似直線の式の a と b が入ったndarray 形式のデータを得る
p = np.polyfit(x, y, 1)

# 一次関数の式のオブジェクトを生成する
f = np.poly1d(p)

# 散布図と近似直線を描く
plt.scatter(x, y)
plt.plot(x, f(x), color="black")
plt.show()

# %% [markdown]
# ## 参考資料：Seaborn

# %%
import seaborn as sns # これも慣習

x = [7, 8, 11, 14, 17, 21, 22, 26, 29, 30]
y = [19, 36, 43, 54, 55, 64, 88, 90, 92, 97]

sns.set(style="whitegrid") # ここでスタイルを指定; ほかにもwhite, dark, darkgrid, ticksがある
plt.plot(x, y)
plt.show()
